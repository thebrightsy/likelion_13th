# %%
# In the event that there is a significant rise in coronavirus cases and hospitalisations this winter, 
# would you support or oppose the following measures being re-introduced?
# Compulsory facemasks in shops and public transport
# 올 겨울에 코로나 케이스와 입원 환자수가 늘어난다면 가게나 대중교통에서 마스크 착용 의무화에 찬성할 것인가?
# 80% 이상이 마스크 착용 의무화에 찬성한다.

import matplotlib.pyplot as plt

ratio = [81, 14, 6]
labels = ['Support', 'Oppose', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# And how likely or unlikely do you think it is the following will actually end up happening this winter?
# Compulsory facemasks in shops and public transport
# 올 겨울에 가게나 대중교통에서 마스크 착용 의무화가 될 것이라고 생각하는가?
# 가게나 대중교통에서 마스크 착용 의무화에 반대하는 사람들 중의 1/3 정도가 올 겨울부터 마스크 착용이
# 의무화 될 것이라고 예상한다. 올 겨울에 가게나 대중교통에서 마스크 착용이 의무화 될 것이라고 생각하는 사람들이 
# 압도적으로 많다.

import matplotlib.pyplot as plt

ratio = [84, 9, 6]
labels = ['Likely', 'Unlikely', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# In the event that there is a significant rise in coronavirus cases and hospitalisations this winter, 
# would you support or oppose the following measures being re-introduced?
# Vaccine passports being required for large indoor and outdoor events
# 올 겨울에 코로나 케이스와 입원 환자수가 늘어난다면 국내외 대거 이동시 백신 여권을 요구하는 것에 찬성하는가?
# 65%이상이 백신 여권을 찬성하고 있다.

import matplotlib.pyplot as plt

ratio = [67, 22, 11]
labels = ['Support', 'Oppose', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# And how likely or unlikely do you think it is the following will actually end up happening this winter?
# Vaccine passports being required for large indoor and outdoor events
# 올 겨울에 국내외 대거 이동시 백신 여권을 요구할 것이라고 생각하는가?
# 백신 여권을 찬성하는 여론만큼 올 겨울부터 백신 여권 정책이 시행될 것이라고 예상하고 있다.

import matplotlib.pyplot as plt

ratio = [60, 28, 12]
labels = ['Likely', 'Unlikely', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# In the event that there is a significant rise in coronavirus cases and hospitalisations this winter, 
# would you support or oppose the following measures being re-introduced?
# Government advice to work from home where possible
# 올 겨울에 코로나 케이스와 입원 환자수가 늘어난다면 정부가 가능한 재택근무를 권장하는 것에 찬성하는가?
# 거의 80%가 재택근무에 찬성하고 있다.

import matplotlib.pyplot as plt

ratio = [77, 13, 10]
labels = ['Support', 'Oppose', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# And how likely or unlikely do you think it is the following will actually end up happening this winter?
# Government advice to work from home where possible
# 올 겨울에 정부가 가능한 재택근무를 권장하게 될 것 같은가?
# 재택근무에 찬성하는 여론과 결과가 비슷하여 정부가 재택근무를 권장하고 시행할 것을 원하고 있는 것으로 보인다.

import matplotlib.pyplot as plt

ratio = [77, 15, 9]
labels = ['Likely', 'Unlikely', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# In the event that there is a significant rise in coronavirus cases and hospitalisations this winter, 
# would you support or oppose the following measures being re-introduced?
# Schools being closed
# 올 겨울에 코로나 케이스와 입원 환자수가 늘어난다면 학교를 닫는 것에 찬성하는가?
# 코로나가 심해도 학교를 닫는 것을 절반 이상 원하지 않는다.

import matplotlib.pyplot as plt

ratio = [29, 52, 19]
labels = ['Support', 'Oppose', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# And how likely or unlikely do you think it is the following will actually end up happening this winter?
# Schools being closed
# 올 겨울에 학교가 닫게 될 것 같은가?
# 코로나가 심해도 학교를 닫는 것이 어떤지에 대해서 잘 모르겠다고 응답한 사람들의 1/3정도가 
# 올 겨울에는 학교를 닫지 않게 될 것 같다고 의견을 옮겼다.

import matplotlib.pyplot as plt

ratio = [27, 62, 12]
labels = ['Likely', 'Unlikely', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# In the event that there is a significant rise in coronavirus cases and hospitalisations this winter,
# would you support or oppose the following measures being re-introduced?
# A full national lockdown, as happened in 2020
# 올 겨울에 코로나 케이스와 입원 환자수가 늘어난다면 2020년처럼 전국 봉쇄조치에 찬성하는가?
# 절반 이상이 전국 봉쇄 조치에 반대하고 있다.

import matplotlib.pyplot as plt

ratio = [32, 52, 17]
labels = ['Support', 'Oppose', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# And how likely or unlikely do you think it is the following will actually end up happening this winter?
# A full national lockdown, as happened in 2020
# 올 겨울에 2020년처럼 전국이 봉쇄조치가 될 것 같은가?
# 64% 정도 올 겨울 전국 봉쇄 조치가 될 것으로 예상하고 있다. 
# 절반 이상이 전국 봉쇄 조치를 반대하고 있지만 여전히 과반수 이상이 현재 코로나 상황을 불안해하고 있다.

import matplotlib.pyplot as plt

ratio = [23, 64, 13]
labels = ['Likely', 'Unlikely', 'Dont know']

explode = [0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 Nightclub에서 얼마나 편안함을 느낄 것인가?
# Nightclub에 가는 것을 꺼려하거나 매우 불편함을 느낀다는 응답이 80%다.

import matplotlib.pyplot as plt

ratio = [9, 9, 15, 39, 2, 26]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 Wedding에서 얼마나 편안함을 느낄 것인가?
# 58% 절반 이상이 Wedding에 가는 것을 편안하게 느낀다.

import matplotlib.pyplot as plt

ratio = [20, 36, 22, 12, 4, 5]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 Pub or bar에서 얼마나 편안함을 느낄 것인가?
# Pub or bar에 가는 것을 편하게 생각하는 사람과 불편하다고 생각하는 사람의 비율이 거의 비슷하다.

import matplotlib.pyplot as plt

ratio = [18, 29, 25, 20, 2, 6]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 운동경기와 축제와 같은 대형 실외 행사에서
# 얼마나 편안함을 느낄 것인가?
# 대형 실외 행사에 가는 것을 편하게 생각하는 사람과 불편하다고 생각하는 사람의 비율이 거의 비슷하다.

import matplotlib.pyplot as plt

ratio = [20, 30, 23, 16, 2, 10]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 콘서트나 공연과 같은 대형 실내 행사에서
# 얼마나 편안함을 느낄 것인가?
# 대형 실내 행사에 가는 것을 절반 이상이 불편하게 생각한다.
import matplotlib.pyplot as plt

ratio = [12, 21, 25, 31, 3, 8]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
# If all coronavirus restrictions end this summer (such as mask-wearing and social distancing), how comfortable or 
# uncomfortable would you feel in the following places/events?
# 만약에 마스크 착용이나 사회적 거리두기와 같은 모든 제한이 올 여름에 끝난다면 대중교통에서
# 얼마나 편안함을 느낄 것인가?
# 대중교통을 이용하는 것을 절반 이상이 불편하게 생각한다.
import matplotlib.pyplot as plt

ratio = [12, 23, 28, 29, 2, 6]
labels = ['Very comfortable', 'Fairly comfortable ', 'Fairly uncomfortable', 'Very uncomfortable', 'Dont know', 'Not applicable - I never go to this type of place/event anyway']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#ffc000', '#8fd9b6']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
